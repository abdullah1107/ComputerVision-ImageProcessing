# %%
#load the necessary packages
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#method for display image
def display_image(image, cmap=None):
    fig = plt.figure(figsize = (12, 10))
    ax = fig.add_subplot(111)
    ax.imshow(image, cmap)

# %%
#read a normal image
image = cv2.imread('images/deer.jpg')

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# (400, 600, 3)

# %%
#resize the image
image = cv2.resize(image,(400, 250))
plt.imshow(image)

# %%
#after resize image
image.shape
# Out:
# (250, 400, 3)

# %%
#create a blank image
blank_img = np.zeros(shape = (450, 500, 3), dtype = np.int8)
original_blank_img = blank_img

# %%
plt.imshow(blank_img)

# %%
(b,g,r) = blank_img[0,0]
print("pixel at (0,0) R: %d, G: %d, B: %d" %(r,g,b))
# Out:
# pixel at (0,0) R: 0, G: 0, B: 0

# %%
blank_img[0,0] = (0, 0, 255)
(b,g,r) = blank_img[0,0]
print("pixel at (0,0) R: %d, G: %d, B: %d" %(r,g,b))
# Out:
# pixel at (0,0) R: -1, G: 0, B: 0

# %%
#how change corner of an image
corner = original_blank_img[0:100, 0:200]
#plt.imshow(corner)
original_blank_img[0:100, 0:200] = (0,0,255)
plt.imshow(original_blank_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
