# %%
#import necessary packages
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load image from images folder
image_dog = cv2.imread('images/dog.jpg')

# %%
#plot image
plt.imshow(image_dog)

# %%
#showing image using cv2
cv2.imshow("image", image_dog)
cv2.waitKey(0)
